# %% [markdown]
# <a href="https://colab.research.google.com/github/jcdumlao14/My-Notes-ml-zoomcamp2022/blob/main/week5_notes_deployingMLmodels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **5. Deploying Machine Learning Models**

# %% [markdown]
# # **5.1 Introduction** (video 1)

# %% [markdown]
# ![Diagram 1.png](data:image/png;base64,...)

# %% [markdown]
# * Marketing service this contain Information about all the users and want to identify whether this user is going to churn so what marketing service can do is send a request to the churn service with information about the user then get back the predictions and based on these predictions the marketing service can decide whether they want to send a promotional email 25% discount

# %% [markdown]
# ![Diagram 2.png](data:image/png;base64,...)

# %% [markdown]
# * We will use flask which is a framework for creating web services in python then we want to isolate the dependencies for this service in such a way that they don't interfere with other services that we have on our machine so we want to create a special environment for python dependencies and for that we will use pipenv then we add another layer on the top layer will be with system dependencies and for that, we will use docker and then finally, after all, what we will do is we will deploy this in a cloud, so this clouds we'll take the container and deploy to AWS elastic bin stroke

# %% [markdown]
# # **5.2 Saving and loading the model**(video 2)
#
# * Saving the model to pickle
# * Loading the model from the pickle
# * Turning our notebook into a python script

# %% [markdown]
# * We trained in jupyter notebook and saving it into a file and then we will also take this notebook who turn this into a python script for training our model and for saving this model into a file.
# * Let's go to the notebook, it contains the most important code from the previous week that is used for preparing the dataset.
# * let's just go through this, you already put all the inputs on the top, we did a bit of cleaning everything for training the model that we need is already here.
# * Data preparationg, data splitting all the variables that we have two functions train and predict.
# * The we wrote in the previous week, we'll just use them and thses are the parameters of the model, this we're going to join a model with the c equals to one and we will use five splits for evaluating our model using cross validation.
# * Let's run the code uses k-fold, five-fold, cross-validaton to train a model and evaluate it.
# * Make sure that our model is perfoming well, have the results, look at the scores.
# * We train our final model and we make sure that results look okay, we train our final model and look AUC for the model on the training data.
# * Take the model and put this in web service in such a way that the marketing services  can use our model to score the customers
# * Use this model we cannot do this from jupyter notebook, and now we need to save this model to be able to load it later.
#
# cont. please refer to week5_notes_Deployment Machine Learning Model.

# %% [markdown]
# ![VSC5.png](data:image/png;base64,...)

# %% [markdown]
# # **5.3 Web services: introduction to Flask**(video 3)

# %% [markdown]
# ![Diagram 3.png](data:image/png;base64,...)

# %% [markdown]
# * Let's say we have our web services and we have a user of our web service, somebody who wants to make a request, so they send the request and they send some information these requests for example if you go to google like I did and look for web service, you send a request and then there are some parameters like query equals web service this is what i sent here so **q equal web service** and then for spaces to use plus then I get back result with whatever web service wants to make with the query in this particular case if we're taking about google, so google returns us a web page with different results.
# * Let's say you google machine learning zoomcamp it will return some results and one of them will be a GitHub repo which you can also start this web service is a service that you communicate with over a network using some protocol, usually, we use is tcp.
# * We can use flask for implementing that and it takes care of all these internals all we need to know is how we can communicate with this.

# %% [markdown]
# * Let's create a simple service in that you send a query to a ping address and it replies with punk, which is all it does.
# * How to create web services with flask it's quite simple so let's do that on Visual Studio code.

# %% [markdown]
# ![VSC 4.png](data:image/png;base64,...)

# %% [markdown]
# # **5.4 Serving the churn model with Flask(video 4)**

# %% [markdown]
# ![VSC 2.png](data:image/png;base64,...)

# %% [markdown]
# # **5.5 Python virtual environment: Pipenv (video 5)**

# %% [markdown]
# ![Diagram 6.png](data:image/png;base64,...)

# %% [markdown]
# * Pip install and then library name for example scikit-learn when we do this what happen in your system where you type inthis command it looks up in this path variable and it sees what kind of pip your talking about and let's say if you use anaconda for this lesson, then pip usually coming from you home directory then you have anaconda three and then is a folder called **bin**, then in this bin you have pip, you have python and have other, when you type pip install second term it uses pip from this location or whatever location you have on your path variable it uses this pip and the this pip goes to **ip.org** which is the python package index by python pi package index, then it finds the second one here and it installs the latest version because here you will notice that we don't specify a version, installing the latest one you can execute this command p goes to pipy if fetches the scikit-learn wheel or some other format so there is some package and that it installs back to the python that you have on your path variable so it goes somewhere in this anaconda folder there is a folder for your libraries and goes there, let's imagine a scenario where we have two applications.

# %% [markdown]
# ![Diagram 7.png](data:image/png;base64,...)

# %% [markdown]
# * We have our churn services = 0.24.2 and by the way this how you can specify the exact package, let's say if you wan to use pip install an exact version of a package you write pip install scikit-learn and then you use equals equals and then the version you want to install, the churn service needs and we have other service let's say lead scoring service that we use to estimate what is the probability that this potential client will become an actual client and for example this leading scoring service use scikit-learn of the latest version so it uses scikit-learn 1.0 and if we have two such services in our system our churn service depends on the version of scikit-learn and lead scoring services depends on the scikit-learn.
# * There are two different version of scikit-learn for example in this version there is something new that doesn't exist here, that's why we need to make sure that everything that the lead scoring service needs is there and at the same time there could be some things that were removed, for example this version of the library we still need to make sure that the churn service still keeps running, we need to find a way to keep them separated because if we just use the system python or whatever python we have in our path variable we're risking that if we need to run two projects they will have conflicts, they need a different version of the library to solve this problem what we usually do is use a virtual environment, the idea there is we put these two different services into different virtual environments and they stay separated this environment has its libraries and its version of libraries and these services do not depend on each other.

# %% [markdown]
# ![Diagram8.png](data:image/png;base64,...)

# %% [markdown]
# * We have our churn service and we have our leading scoring service so each of them lives in its own environment and isolated from the rest, for example for churn service it uses its own python which can live for example in somewhere **venv** and churn being python and lead scoring service has it's own python that lives in venv and lead bin python so they have different python each of these python has its own packages and when we do pip install it uses pip from python and then it install a package when we do scikit-learn then it installs this scikit-learn to this python and the same happens for the lead scoring service when we do pip install here then it uses this python its own python and then when you install scikit-learn you can install a different version of scikit-learn which will have no conflict with the churn services we have no conflicts on this way you can keep these things separated so the churn service will have it's own dependencies and its own environment and the lead scoring service will have its own dependencies and its own environment so this type of separation.
# * If you use **ubuntu** so both of them live from the same laptop on the same operating system the same ubuntu they just have different, let's say folders where they keep dependencies and this is how they manage to resolve the conflict each of them keeps their own personal python that is isolated from the pythons of other projects this seperation is called **virtual environments**.
#
# * **VIRTUAL ENVIRONMENT**
#
#   * Vertual env/venv
#   * conda
#   * pipenv
#   * peotry
#
# * There are multiple way of managing virtual environmnent so you have the more classic python one it's called **virtual env** its a built-in package for python called **env** you can use for creating environments and then there is also conda this is what anaconda uses and if you following the instruction from the setup and conda here was creating a virtual environment this was isolated from main anaconda python interpreter we activated the environment you can use conda for that and the other libraries one is pipenv and then there is also poetry.
# * We use pipenv or poetry so there is no big difference the only reason I chose pipenv is it's officially recommended package management from the python community but they work pretty similar.

# %% [markdown]
# Visual studio code

# %% [markdown]
# # **5.6 Environment Management: Docker**(video 6)

# %% [markdown]
# ![Diagram 4.png](data:image/png;base64,...)

# %% [markdown]
# * Docker we can get even more isolation because with docker every service let's say we have a service that we call **churn service** and then we have **lead scoring service** and instead of creating virtual environment what we can do is put each thing in a separati container we'll have one container for leading scoring service and other container for churn service and these services will not know anything about each other, they will live in complete isolation from the point of view of our churn service it will see I'll will think that it's the only thing that is running on this computer, so this is like a special box where we put our service and it only uses the things it needs and there is nothing else running that is not needed for this particular service, we can specify and kind of environment we need for example let's say if we need ubuntu of some specific version let's say 18.04 then we have that and if for leads coding project we need a newer version of ubuntu perhaps like twenty point zero four then it's also fine and then we can have some other service maybe email service, a service that marketing service can use for sending emails, maybe this email service is running on parallel and uses amazon linux and then so we have all these different service that have different requirements, different system requirement they might use different  version of ubuntu different libraries so for example may be here we need to have the special version of  plus plus compiler it uses some library like I don't know exboost that we need to compile, so then here we install like this g-plus plus but here for the churn service, so they use the environment that they need and then of course each of them has its own python, but these python are completely isolated from each other and then everything lives on a host machine, let's see this is our host machine can be mac windows or some linux doesn't matter, let's say it's ubuntu 18.04 and then this host can have as many different containers with different types of Linux is different types of operating systems they're all living together in isolation from each other and then each of them will have its dependencies like here, we will have scikit learn of version like 0.20 something, and for example for lead scoring the version of scikit-learn will be 1.0 so this is why within docker and the main advantage of docker, let's say this is our host but what we can do is we can take our service like our churn service

# %% [markdown]
# ![Diagram 5.png](data:image/png;base64,...)

# %% [markdown]
# * We can just take it and easily deploy to the cloud, just take it as this, we put everything that is needed inside this docker container and we just put this in the cloud the container already contains everything we need so that's why for us it's easy to just go ahead and deploy things.
# * google just type **python docker image**
# * let's first run the docker image, lets go to docker hub which contains all the images of python, it shows now all the tags and here take the first is the version of python, let's say we use python 3.8 slim, so slim means that this image is optimized it's very small.
# * Uses something Debian based so we can use opt-get and the usual things we do in ubuntu, we will try to run this image for that we use the docker run command and then we specify the image we want to, we need to tell docker that we want to have access to the terminal so that's why we need this id and after playing with this image we want to remove it from our system we don't want to keep it that's why I have this minus minus run. write **$ docker run it --rm python: 3.8.12-slim**.
# * Only the main docker only docker container will be affected and the rest of the system will not be, here we can use pip to install everything we need like pip install.
# * Everything we can do for this docker image we can define in the docker file and save it as a docker file.
# * whatever we do here it stays here.

# %% [markdown]
# ![diagram0.png](data:image/png;base64,...)
