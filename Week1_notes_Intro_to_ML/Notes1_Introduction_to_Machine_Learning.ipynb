# %% [markdown]
# # **Machine Learning Zoomcamp 2022**
#
# ### My Notes - Week 1: Introduction to Machine Learning
#
# Instructor: [Alexey Grigorev](https//bit.ly/3BxeAob)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Introduction to Machine Learning**
#
# ### What is machine learning?
#
# **Machine Learning** is the use and development of computer systems that can learn and adapt without following explicit instructions, by using algorithms and statistical models to analyze and draw inferences from patterns in data.
#
# * A combination between attributes of an object(features) and information associated with a value to be known(target) is the perfect cocktail to create models.
#
# * Machine Learning prefers to tell the machine where to go and in turn give it a set of elements that it can use to reach the desired result.
#
# * Talk about the car price prediction

# %% [markdown]
# # **Machine Learning VS Rule Base Systems**
#
# Session # 1.2 Plan
#
# * A rule-based system for spam detection
# * Using Machine Learning for spam detection
# * Extraction  features for Machine Learning

# %% [markdown]
# Email System
#
# * will illustrate this using a spam detection example so imagine that you have system emails, usually we have Gmail or outlook, talk to your collegues for work related things for chatting with friends send emails receive emails and then at some point users of ou system start complaining about unsolicited emails so it can be promotions about discounts that people have aren't subscribed to,so this unsolicited promotions or even fraudulent message that try to, people try to cheat other people and ask them to give some money and we want to fight this, so we want to fight all these emails we don't want our users to receive these emails, so we want to develop a spam detection system, so we want to take these emails, and let's say, we have a folder for spam and send all the emails that are spam, so this system we want to develop.
#
# * We want to build a classifier that classifies things into spam or not spam.
#
# * What we can do is we can just take all the spam messages
#
# * To analyze the data and we see that all emails that came from this particular email promotion are online.com they're all spam messages

# %% [markdown]
# Rules
#
# * if sender = promotions @online.com then "spam"
# * if a title contains "tax review" and the sender domain is "online.com" then "spam"
# * if the body contains a work "deposit"
#   * **If sender domain is "test.com" then "spam"**
#   * **If body >= 100 words then spam**
# * otherwise "good email"
#
# We can write a simple program and then code these rules using for

# %%
"""Code"""

def detect_spam(email):
  if email.sender == 'promotion@online.com':
    return SPAM
  if contains(email.title,['tax', 'review']) and domain(email.sender,'online.com'):
    return SPAM
  
  return GOOD

# %% [markdown]
# * We deploy the system and it works
# * All these spam messages contain deposits, all good messages don't contain deposit
# * We implement this it works
# * These never-ending because spam keeps changing the rules
# * We need to keep them up to date so constantly need to change them
# * Use Machine learning so to solve the problem in a different way

# %% [markdown]
# Machine Learning
#
# * Get data
# * Define & calculate features
# * Train and use the model
#   * We need to extract some features from these emails
#   * Use to describe emails all these characteristics of emails
#   * To train the model then after that we can once we train the model for classifying messages into spam and not spam
#   * We can take emails that are spam
#   * We can take emails that are not spam and we can use them for training in a model
#   * We need to define and calculate features

# %% [markdown]
# Features
#
# * Length of title > 10? true/false
# * Length of body > 10? true/false
# * Sender "promotions@online.com"? true/false
# * Sender "hpYOSKml@test.com"? true/false
# * Sender domain "test.com"? true/false
# * Description contains "deposit"? true/false
#
#   * if the title is longer than 10 than this feature is true
#   *if the title is 10 or less than this feature is false
#   * this particular sender or the domain or the deposit is actually from the rule we have
#   * a rule-based system - these six features are called binary features

# %% [markdown]
# # **Supervised Machine Learning**
#
# **Supervise Machine Learning** is teaching a machine to find pattern from examples or training data that are composed of the feature and the target variable. As a results, we will obtain a function that later, when applied to other example, will result in a value close enough to our target value.
#
# * To extract the prediction the price of a car
# * The defferent examples are spam and non-spam prediction message
# * We do show pictures, we do show text but most of the time we need to extract features
# * We want to predict if spam or not spam, one means spam zero means not spam

# %% [markdown]
# Using some mathematical notation, the goal of supervised machine learning is to find a function g. when applied to a matrix cap X, values are sufficiently close to our vector y.
#
# where g is the model, X is the matrix of features, composed of observations(rows) and features(columns), and y is the target variable, with the information that we wish to predict.
#
# y = as one dimensional array
#
# X =  as two dimensional array

# %% [markdown]
# What is classification in supervised machine learning?
#
# In **machine learning, classification is a supervised learning** concept which basically categorizes a set of data into classes. The most common classification problems are – speech recognition, face detection, handwriting recognition, document classification, etc.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# There are several type of supervised machine learning classification
#
# * Multiclass
# * Binary
# * Ranking

# %% [markdown]
# # **CRISP DM**

# %% [markdown]
# # **What is CRISP-DM in machine learning?**
#
# CRISP-DM, which **stands for Cross-Industry Standard Process for Data Mining**, is an industry-proven way to guide your data mining efforts. As a methodology, it includes descriptions of the typical phases of a project, the tasks involved with each phase, and an explanation of the relationships between these tasks.
#
# Creating a machine learning system involves more than just selecting a model, training it, and applying it to new data. There are frameworks that help us organize machine learning projects.

# %% [markdown]
# ## According to CRISP-DM, the machine learning process has six steps:
#
# 1. Business Understanding
# 2. Data Understanding
# 3. Data Preparation
# 4. Modeling
# 5. Evaluation
# 6. Deployment

# %% [markdown]
# ## **CRISP DM**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Each phase covers typical tasks:
#
# * In the business understanding step, we try to identify the problem, to understand how we can solve it, and to decide whether machine learning will be a useful tool for solving it.
#
# * In the data understanding step, we analyze available datasets and decide whether we need to collect more data.
#
# * In the data preparation step, we transform the data into tabular the form that we can use as input for a machine learning model.
#
# * When the data is prepared, we move to the modeling step, in which we train a model.
#
# * After the best model is identified, there’s the evaluation step, where we evaluate the model to see if it solves the original business problem and measure its success at doing that.
#
# * Finally, in the deployment step, we deploy the model to the production environment.

# %% [markdown]
# ### Example
#
# Suppose we want to build a spam detection system: for each email we get, we want to determine if it’s spam or not. If it is, we want to put it into the “spam” folder.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**1. Business understanding**
#
# * Our users compalain about spam
# * Analyze the problem and the existing solution and try to determine if adding machine learning to that system will help us stop spam messages.
# * Need to define the goal and how to measure it.
#   * The goal could be “Reduce the number of reported spam messages” or “Reduce the number of complaints about spam that customer support receives per day",

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **2. Data understanding**
#
# * Try to identify the data sources we can use to solve the problem.
#
#   * We have a report spam buttom
#   * Is the data behind this buttom good enough?
#   * Is it reliable?
#   * Do we track it correctly?
#   * Is the dataset large enough?
#   * Do we need to get more data?
#
# * Report Spam button, for example, we can get the data generated by the users who marked their incoming emails as spam.
#
# * This data may be not good enough
#   * One reason could be that the dataset is too small for us to learn any useful patterns.
#
#   * Another reason could be that the data is too noisy.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **3. Data Preparation**
#
# * We clean the data and transform data into a table so we can put it into machine learning
#
#   * For the spam example, we transform the dataset into a set of features that we feed into a model.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **4. Modeling**
#
# * machine learning model to use and how to make sure that we get the best out of it.
#
# * to know how we will measure the performance of the models to select the best one.
#
#   * which model to choose?
#     * Logistic Regression
#     * Deep Neural Network
#     * Decision Tree
#     * many others to solve the spam problem.
#
# * On how well the model predicts spam messages and chooses the one that does it best.
#
# * setting a proper validation framework is important
#   * go back to the data preparation step to write some code to compute that feature
#   * When the code is done, train the model again to check whether this feature is good.
#   * Check whether this change improves the model’s performance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **5. Evaluation**
#
# * We set a goal in the business understanding step
# * We also define the way of establishing whether the goal is achieved.
# * By looking at an important business metric and making sure that the model moves the metric in the right direction.
# * In the spam-detection case, the metric could be the number of people who click the Report Spam button or the number of complaints about the issue we’re solving that customer support receives.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **6. Deployment**
#
# * After the model is deployed, we use everything we learned in all the steps and go back to the first step to reflect on what we achieved (or didn’t achieve).
# * We may realize that our initial goal was wrong and that what we actually want to do is not reduce the number of reports, but increase customer engagement by decreasing the amount of spam.
# * We go all the way back to the business understanding step to redefine our goal.
# * We evaluate the model again, we use a different business metric to measure its success.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Multiple comparisons problem
#
# * Divide your data into three different dataset: Training, Validation, and Test
#
# * With the Training Dataset train the models.
#
# * with the Validation Dataset you can evaluate them and get the Accuracy values.
#
# * Select the best model based on the best Accuracy score or some other performance metric.
#
# * Apply the selected model to the Test Dataset
#
# * Compare the performance metrics obtained from both the validation and Test Dataset,if they match you can be more confident of your correct choice, if not, you may want to consider other options.
